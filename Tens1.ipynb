# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import losses
from scipy.stats import norm
# Out:
# WARNING:tensorflow:From C:\Users\Phanindra.Namana\Desktop\Project\cuda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load data – training and test
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 3s 0us/step

# %%
#Normalize and Reshape images (flatten)
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr_flat, x_te_flat = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)

# %%
print(x_tr.shape, x_te.shape)
print(x_tr_flat.shape, x_te_flat.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000, 784) (10000, 784)

# %%
batch_size, n_epoch = 100, 50
n_hidden, z_dim = 256, 2

# %%
plt.imshow(x_tr[1]);

# %%
def sampling(args):
    mu, log_var = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mu + K.exp(log_var) * eps

# %%
# Encoder - from 784->256->128->2
inputs_flat = Input(shape=(x_tr_flat.shape[1:]))
x_flat = Dense(n_hidden, activation='relu')(inputs_flat) # first hidden layer
x_flat = Dense(n_hidden//2, activation='relu')(x_flat)  # second hidden layer

# hidden state, which we will pass into the Model to get the Encoder.
mu_flat = Dense(z_dim)(x_flat)
log_var_flat = Dense(z_dim)(x_flat)
z_flat = Lambda(sampling, output_shape=(z_dim,))([mu_flat, log_var_flat])
# Out:
# WARNING:tensorflow:From C:\Users\Phanindra.Namana\Desktop\Project\cuda\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
#Decoder - from 2->128->256->784
latent_inputs = Input(shape=(z_dim,))
z_decoder1 = Dense(n_hidden//2, activation='relu')
z_decoder2 = Dense(n_hidden, activation='relu')
y_decoder = Dense(x_tr_flat.shape[1], activation='sigmoid')
z_decoded = z_decoder1(latent_inputs)
z_decoded = z_decoder2(z_decoded)
y_decoded = y_decoder(z_decoded)
decoder_flat = Model(latent_inputs, y_decoded, name="decoder_conv")

outputs_flat = decoder_flat(z_flat)

# %%
# variational autoencoder (VAE) - to reconstruction input
reconstruction_loss = losses.binary_crossentropy(inputs_flat,
                                                 outputs_flat) * x_tr_flat.shape[1]
kl_loss = 0.5 * K.sum(K.square(mu_flat) + K.exp(log_var_flat) - log_var_flat - 1, axis = -1)
vae_flat_loss = reconstruction_loss + kl_loss

# Build model
#  Ensure that the reconstructed outputs are as close to the inputs
vae_flat = Model(inputs_flat, outputs_flat)
vae_flat.add_loss(vae_flat_loss)
vae_flat.compile(optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\Phanindra.Namana\Desktop\Project\cuda\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Phanindra.Namana\Desktop\Project\cuda\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# train
vae_flat.fit(
    x_tr_flat,
    shuffle=True,
    epochs=n_epoch,
    batch_size=batch_size,
    validation_data=(x_te_flat, None),
    verbose=1
)
# Out:
# Epoch 1/50
# 600/600 [==============================] - 5s 7ms/step - loss: 198.5791 - val_loss: 171.6990
# Epoch 2/50
# 600/600 [==============================] - 4s 7ms/step - loss: 167.5035 - val_loss: 163.8060
# Epoch 3/50
# 600/600 [==============================] - 4s 6ms/step - loss: 160.6992 - val_loss: 158.0001
# Epoch 4/50
# 600/600 [==============================] - 4s 6ms/step - loss: 155.9289 - val_loss: 154.2729
# Epoch 5/50
# 600/600 [==============================] - 4s 6ms/step - loss: 152.8595 - val_loss: 152.0271
# Epoch 6/50
# 600/600 [==============================] - 4s 6ms/step - loss: 150.4469 - val_loss: 149.9274
# Epoch 7/50
# 600/600 [==============================] - 5s 8ms/step - loss: 148.3390 - val_loss: 147.8984
# Epoch 8/50
# 600/600 [==============================] - 5s 8ms/step - loss: 146.6075 - val_loss: 146.5024
# Epoch 9/50
# 600/600 [==============================] - 5s 8ms/step - loss: 145.2841 - val_loss: 145.0016
# Epoch 10/50
# 600/600 [==============================] - 5s 9ms/step - loss: 144.2538 - val_loss: 144.2221
# Epoch 11/50
# 600/600 [==============================] - 5s 8ms/step - loss: 143.3832 - val_loss: 143.5119
# Epoch 12/50
# 600/600 [==============================] - 5s 8ms/step - loss: 142.5280 - val_loss: 143.2340
# Epoch 13/50
# 600/600 [==============================] - 5s 8ms/step - loss: 141.8951 - val_loss: 143.0495
# Epoch 14/50
# 600/600 [==============================] - 5s 8ms/step - loss: 141.5319 - val_loss: 142.2403
# Epoch 15/50
# 600/600 [==============================] - 5s 9ms/step - loss: 141.0732 - val_loss: 141.6405
# Epoch 16/50
# 600/600 [==============================] - 5s 9ms/step - loss: 140.5382 - val_loss: 141.2005
# Epoch 17/50
# 600/600 [==============================] - 5s 8ms/step - loss: 140.3123 - val_loss: 140.7570
# Epoch 18/50
# 600/600 [==============================] - 5s 9ms/step - loss: 139.9884 - val_loss: 140.1913
# Epoch 19/50
# 600/600 [==============================] - 5s 8ms/step - loss: 139.5733 - val_loss: 140.2289
# Epoch 20/50
# 600/600 [==============================] - 5s 8ms/step - loss: 139.2332 - val_loss: 139.6797
# Epoch 21/50
# 600/600 [==============================] - 5s 8ms/step - loss: 138.9967 - val_loss: 139.7022
# Epoch 22/50
# 600/600 [==============================] - 5s 8ms/step - loss: 138.7368 - val_loss: 139.5469
# Epoch 23/50
# 600/600 [==============================] - 5s 8ms/step - loss: 138.3910 - val_loss: 138.7600
# Epoch 24/50
# 600/600 [==============================] - 5s 8ms/step - loss: 137.9722 - val_loss: 138.9394
# Epoch 25/50
# 600/600 [==============================] - 5s 8ms/step - loss: 137.6197 - val_loss: 138.4457
# Epoch 26/50
# 600/600 [==============================] - 5s 8ms/step - loss: 137.6892 - val_loss: 138.1326
# Epoch 27/50
# 600/600 [==============================] - 5s 8ms/step - loss: 137.3338 - val_loss: 138.5733
# Epoch 28/50
# 600/600 [==============================] - 5s 9ms/step - loss: 137.0544 - val_loss: 137.9000
# Epoch 29/50
# 600/600 [==============================] - 4s 7ms/step - loss: 137.0079 - val_loss: 137.9789
# Epoch 30/50
# 600/600 [==============================] - 4s 7ms/step - loss: 136.7149 - val_loss: 138.1608
# Epoch 31/50
# 600/600 [==============================] - 5s 8ms/step - loss: 137.1916 - val_loss: 137.8762
# Epoch 32/50
# 600/600 [==============================] - 5s 9ms/step - loss: 136.6295 - val_loss: 138.1828
# Epoch 33/50
# 600/600 [==============================] - 5s 8ms/step - loss: 136.7072 - val_loss: 137.1499
# Epoch 34/50
# 600/600 [==============================] - 5s 9ms/step - loss: 136.2375 - val_loss: 137.9626
# Epoch 35/50
# 600/600 [==============================] - 5s 9ms/step - loss: 135.9758 - val_loss: 137.3728
# Epoch 36/50
# 600/600 [==============================] - 6s 10ms/step - loss: 135.7467 - val_loss: 136.8401
# Epoch 37/50
# 600/600 [==============================] - 4s 7ms/step - loss: 135.8374 - val_loss: 137.1987
# Epoch 38/50
# 600/600 [==============================] - 5s 8ms/step - loss: 135.7934 - val_loss: 137.1557
# Epoch 39/50
# 600/600 [==============================] - 5s 9ms/step - loss: 135.6319 - val_loss: 136.8901
# Epoch 40/50
# 600/600 [==============================] - 5s 8ms/step - loss: 135.5378 - val_loss: 136.6934
# Epoch 41/50
# 600/600 [==============================] - 6s 9ms/step - loss: 135.3292 - val_loss: 136.3496
# Epoch 42/50
# 600/600 [==============================] - 5s 8ms/step - loss: 135.3390 - val_loss: 136.1821
# Epoch 43/50
# 600/600 [==============================] - 6s 9ms/step - loss: 135.3167 - val_loss: 136.2751
# Epoch 44/50
# 600/600 [==============================] - 8s 13ms/step - loss: 135.0772 - val_loss: 136.4192
# Epoch 45/50
# 600/600 [==============================] - 7s 12ms/step - loss: 135.0428 - val_loss: 136.0396
# Epoch 46/50
# 600/600 [==============================] - 6s 9ms/step - loss: 134.9001 - val_loss: 135.7147
# Epoch 47/50
# 600/600 [==============================] - 6s 9ms/step - loss: 134.9350 - val_loss: 136.1325
# Epoch 48/50
# 600/600 [==============================] - 6s 10ms/step - loss: 134.7307 - val_loss: 135.8124
# Epoch 49/50
# 600/600 [==============================] - 10s 17ms/step - loss: 134.4106 - val_loss: 135.9503
# Epoch 50/50
# 600/600 [==============================] - 8s 14ms/step - loss: 134.3217 - val_loss: 136.2094

# %%
# Build encoders
encoder_f = Model(inputs_flat, z_flat)

# %%
# Plot of the digit classes in the latent space
x_te_latent = encoder_f.predict(x_te_flat, batch_size=batch_size,verbose=0)
plt.figure(figsize=(8, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te, alpha=0.75)
plt.title('MNIST 2D Embeddings')
plt.colorbar()
plt.show()

# %%
plt.imshow(x_te_flat[10].reshape(28,28));

# %%
plt.imshow(x_te_flat[13].reshape(28,28));

# %%
plt.imshow(x_te_flat[2].reshape(28,28));

# %%
plt.imshow(x_te_flat[12].reshape(28,28));

# %%
# calculate vectors for each digit
zero_A = x_te_latent[10]
zero_B = x_te_latent[13]
one = x_te_latent[2]

print(f"Embedding for the first ZERO is  {zero_A}")
print(f"Embedding for the second ZERO is {zero_B}")
print(f"Embedding for the ONE is         {one}")
# Out:
# Embedding for the first ZERO is  [1.4899828  0.97506297]
# Embedding for the second ZERO is [1.2046868 0.6150359]
# Embedding for the ONE is         [-0.5502571 -1.7619675]

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# .gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
sentence = ['Why Mikasa Killed Eren',
            'Why Okabe was not able to save makise',
            'Why Lelouch started the rebellion']

# %%
#Sentences are encoded by calling model.encode()
embedding = model.encode(sentence)

#Preview the embeddings
print(embedding)
# Out:
# [[ 0.09353791  0.8246493  -0.30139038 ...  0.20216489  0.30485532
#    0.20698583]
#  [-0.15477513  0.6065778  -0.45151842 ... -0.32568604  0.2982218
#   -0.21504773]
#  [-0.24690562  0.6309455  -0.76974934 ...  0.29125392  0.51587045
#   -0.8651589 ]]

# %%
embedding.shape
# Out:
# (3, 384)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(embedding[0].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

sns.heatmap(embedding[1].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

sns.heatmap(embedding[2].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

# %%
# Euclidean Distance
L2 = [(zero_A[i] - zero_B[i])**2 for i in range(len(zero_A))]
L2 = np.sqrt(np.array(L2).sum())
print(L2)
# Out:
# 0.45936189359473834

# %%
#An alternative way of doing this
np.linalg.norm((zero_A - zero_B), ord=2)
# Out:
# 0.45936188

# %%
#Calculate L2 distances
print("Distance zeroA-zeroB:", np.linalg.norm((zero_A - zero_B), ord=2))
print("Distance zeroA-one:  ", np.linalg.norm((zero_A - one), ord=2))
print("Distance zeroB-one:  ", np.linalg.norm((zero_B - one), ord=2))
# Out:
# Distance zeroA-zeroB: 0.45936188
# Distance zeroA-one:   3.413783
# Distance zeroB-one:   2.954653

# %%
# Manhattan Distance
L1 = [zero_A[i] - zero_B[i] for i in range(len(zero_A))]
L1 = np.abs(L1).sum()

print(L1)
# Out:
# 0.64532316

# %%
#an alternative way of doing this is
np.linalg.norm((zero_A - zero_B), ord=1)
# Out:
# 0.64532316

# %%
#Calculate L1 distances
print("Distance zeroA-zeroB:", np.linalg.norm((zero_A - zero_B), ord=1))
print("Distance zeroA-one:  ", np.linalg.norm((zero_A - one), ord=1))
print("Distance zeroB-one:  ", np.linalg.norm((zero_B - one), ord=1))
# Out:
# Distance zeroA-zeroB: 0.64532316
# Distance zeroA-one:   4.7772703
# Distance zeroB-one:   4.1319475

# %%
# Cosine Distance
cosine = 1 - np.dot(zero_A,zero_B)/(np.linalg.norm(zero_A)*np.linalg.norm(zero_B))
print(f"{cosine:.6f}")
# Out:
# 0.005765

# %%
zero_A/zero_B
# Out:
# array([1.2368218, 1.5853757], dtype=float32)

# %%
# Cosine Distance function
def cosine_distance(vec1,vec2):
  cosine = 1 - (np.dot(vec1, vec2)/(np.linalg.norm(vec1)*np.linalg.norm(vec2)))
  return cosine

# %%
#Cosine Distance
print(f"Distance zeroA-zeroB: {cosine_distance(zero_A, zero_B): .6f}")
print(f"Distance zeroA-one:   {cosine_distance(zero_A, one): .6f}")
print(f"Distance zeroB-one:   {cosine_distance(zero_B, one): .6f}")
# Out:
# Distance zeroA-zeroB:  0.005765
# Distance zeroA-one:    1.772120
# Distance zeroB-one:    1.699531

# %%
#Dot Product
print("Distance 0-1:", np.dot(embedding[0], embedding[1]))
print("Distance 0-2:", np.dot(embedding[0], embedding[2]))
print("Distance 1-2:", np.dot(embedding[1], embedding[2]))
# Out:
# Distance 0-1: 23.529457
# Distance 0-2: 15.770691
# Distance 1-2: 14.458804

# %%
#Cosine Distance
print("Distance 0-1: ", cosine_distance(embedding[0], embedding[1]))
print("Distance 0-2: ", cosine_distance(embedding[0], embedding[2]))
print("Distance 1-2: ", cosine_distance(embedding[1], embedding[2]))
# Out:
# Distance 0-1:  0.5783413350582123
# Distance 0-2:  0.7211774289608002
# Distance 1-2:  0.7261705100536346
